# %%
import sqlite3
import requests
from bs4 import BeautifulSoup
#https://www.cv.ee/toopakkumised/harjumaa/infotehnoloogia
#/job-ad/twilio-estonia/software-engineer-twilio-flex-sdk-f4162816.html
def find_data (link):
    r = requests.get("https://www.cv.ee" + link)
    html = BeautifulSoup(r.content)
#    title = html.find("span", {"id": "productName"}).get_text()
#    price = html.find("span", {"class": "product-list-current-price"}).get_text()
#    tags = 
    print (html)
        
find_data("/job-ad/twilio-estonia/software-engineer-twilio-flex-sdk-f4162816.html")
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 Strict//EN" "https://www.w3.org/TR/xhtml1/DTD/xhtml1-strict.dtd">
# <html xmlns="https://www.w3.org/1999/xhtml">
# <head profile="https://gmpg.org/xfn/11">
# <title>Job ad - SOFTWARE ENGINEER - TWILIO FLEX, SDK, Tallinn, Veerenni 38, Full-time work, Twilio Estonia | CV-Online</title>
# <meta content="Job ad - SOFTWARE ENGINEER - TWILIO FLEX, SDK, Tallinn, Veerenni 38, Full-time work, Twilio Estonia | CV-Online" http-equiv="title"/>
# <meta content="Our good client, TWILIO ESTONIA, is seeking for a new team member to fulfill the position of SOFTWARE ENGINEER - TWILIO FLEX, SDK located in TALLINN, VEERENNI 38 with working time of FULL-TIME WORK, job ad deadline is 01/07/2020. Apply now!" name="description"/>
# ...

# %%
import sqlite3
import requests
from bs4 import BeautifulSoup
#https://www.cv.ee/toopakkumised/harjumaa/infotehnoloogia
#/job-ad/twilio-estonia/software-engineer-twilio-flex-sdk-f4162816.html
def find_data (link):
    r = requests.get("https://www.cv.ee" + link)
    html = BeautifulSoup(r.content)
    title = html.find("h1").get_text()
    publish = html.find("span", {"class": "application-date"}).get_text()
    
    return [title, publish]
        
#print (find_data("/job-ad/twilio-estonia/software-engineer-twilio-flex-sdk-f4162816.html"))

r = requests.get("https://www.cv.ee/toopakkumised/harjumaa/infotehnoloogia")
html = BeautifulSoup(r.content)
links = html.find_all("div", {"class": "offer_primary_info"})
data = []
for link in links:
    if link["href"] and link.get_text().find("job-ad") > -1:
        print (link["href"])
        #data.append(find_data(link["href"]))
#print (data)
# Out:
# -------------------------------------------------------------------------
# KeyError                                Traceback (most recent call last)
# <ipython-input-29-0b6f36b3bf57> in <module>
#      19 data = []
#      20 for link in links:
# ---> 21     if link["href"] and link.get_text().find("job-ad") > -1:
#      22         print (link["href"])
#      23         #data.append(find_data(link["href"]))
#
# ~/Documents/jupyter/venv/lib/python3.8/site-packages/bs4/element.py in __getitem__(self, key)
#    1366         """tag[key] returns the value of the 'key' attribute for the Tag,
#    1367         and throws an exception if it's not there."""
# -> 1368         return self.attrs[key]
#    1369
#    1370     def __iter__(self):
#
# KeyError: 'href'
