# %%
import requests
from bs4 import BeautifulSoup
r = requests.get("https://www.neti.ee/cgi-bin/teema/TERVIS/Iluteenindus/")
html = BeautifulSoup(r.content)
item = [h3.get_text() for h3 in html.find_all("span", {"class": "out"})]
print(html)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <link href="//www.google-analytics.com" rel="dns-prefetch"/>
# <link href="//ls.hit.gemius.pl" rel="dns-prefetch"/>
# <link href="//netiee.adocean.pl" rel="dns-prefetch"/>
# <link href="//gaee.hit.gemius.pl" rel="dns-prefetch"/>
# <link href="//adocean-ee.hit.gemius.pl" rel="dns-prefetch"/>
# <link href="//fonts.googleapis.com" rel="dns-prefetch"/>
# <link href="//fonts.gstatic.com" rel="dns-prefetch"/>
# <!--[if IE 8]>
# <meta http-equiv="X-UA-Compatible" content="EmulateIE7" />
# <![endif]-->
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <title>NETI: /TERVIS/Iluteenindus</title>
# <meta content="NETI on Eesti parim kataloog ja otsingumootor. NETI igapäevanekasutajate arv ületab 350 000." name="description"/>
# <meta content="Telia" name="author"/>
# <meta content="NETI" name="application-name"/>
# <meta content="Eesti parim kataloog ja otsingumootor" name="msapplication-tooltip"/>
# ...

# %%
import requests
from bs4 import BeautifulSoup
r = requests.get("https://www.neti.ee/cgi-bin/teema/TERVIS/Iluteenindus/")
html = BeautifulSoup(r.content)
item = [a.get_text() for a in html.find_all("h3", {"class": "name inline-block"})]
print(item)
# Out:
# ['Eesti Kosmeetikute Liit', 'Eesti Trihholoogide Liit', 'Kutseliste Juuksurite Vabariiklik Ühendus', 'Eesti Solaariumikoda', 'Abigail', 'Afrodita', 'Airiin', 'Aknalb (Blanka Iluteenused)', 'A&K Salong', 'Anestra Ilustuudio', 'Anne Ilutuba', 'Annely Ilustuudio', 'Antonina', 'APR Olgaor (Nogti)', 'Aroma Style', 'ArtMed Studio', 'Astangu juuksur', 'Astrid Beauty Academy', 'Azalea Beauty', 'Aulis', 'Aurora', 'Aurora Medica', 'Avely Ilusalong', 'Avina', 'A.N.Studio', 'Babor Spa', 'Balfonia', 'Baltic Brows', 'Bazinga Ilusalong', 'Beauté & Serenite', 'Beautiq', 'BeautyArt', 'Beautyday (Caroline Ilutuba)', 'Beauty Evolution', 'Beauty Lounge', 'Beauty Parlour (Kosmeetik Ingrid Koppel)', 'Beauty Passion', 'Beauty Taxi', 'Belle', 'Benessere', 'Bjuuti Stop', 'Bliss Ilusalong', 'Beauty Plaza', 'Beauty Solutions', 'Big Apple', 'Blue Lagoon', 'Braavo', 'Brilliant Ilustuudio', 'Brofix Barbershop', 'Buterfly Beauty Spa', 'B & BLux Group', 'Care', 'Carine Salong', 'Casabella', 'Central (Gardiner Grupp
# ...

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
r = requests.get("https://worldtable.info/gosudarstvo/tablica-rozhdaemosti-po-godam-rossija.html")
html = BeautifulSoup(r.content)
data = []
table = html.find("table")
for tr in table.find_all("tr"):
    data.append([td.get_text() for td in tr.find_all("td")])
data = pd.DataFrame(data[1:], columns=["Год", "Количество"])
print (data)
# Out:
#      Год Количество
# 0   1959  2 796 228
# 1   1960  2 782 353
# 2   1961  2 662 135
# 3   1962  2 482 539
# 4   1963  2 331 505
# ..   ...        ...
# 56  2015  1 944 136
# 57  2016  1 893 256
# 58  2017  1 689 884
# 59  2018  1 599 316
# 60  2019  1 484 517
#
# [61 rows x 2 columns]

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
r = requests.get("https://worldtable.info/gosudarstvo/tablica-rozhdaemosti-po-godam-rossija.html")
html = BeautifulSoup(r.content)
data = []
table = html.find("table")
for tr in table.find_all("tr"):
    data.append([td.get_text() for td in tr.find_all("td")])
data = pd.DataFrame(data[1:])
print (data)
# Out:
#        0          1
# 0   1959  2 796 228
# 1   1960  2 782 353
# 2   1961  2 662 135
# 3   1962  2 482 539
# 4   1963  2 331 505
# ..   ...        ...
# 56  2015  1 944 136
# 57  2016  1 893 256
# 58  2017  1 689 884
# 59  2018  1 599 316
# 60  2019  1 484 517
#
# [61 rows x 2 columns]

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
r = requests.get("https://www.cv.ee/toopakkumised/harjumaa/infotehnoloogia")
html = BeautifulSoup(r.content)
data = []
table = html.find("div", {"class": "cvo_module_offers_wrap"})
for div in table.find_all("div"):
    data.append([div.get_text() for div in div.find_all("h2")])
print (data)
# Out:
# [['Net Group - maailmamuutvad lahendused IT-sektoris'], ['Net Group - maailmamuutvad lahendused IT-sektoris'], [], ['Net Group - maailmamuutvad lahendused IT-sektoris'], ['Net Group - maailmamuutvad lahendused IT-sektoris'], ['Net Group - maailmamuutvad lahendused IT-sektoris'], ['Derivco Estonia – Legendary Gaming Experience'], ['Derivco Estonia – Legendary Gaming Experience'], [], ['Derivco Estonia – Legendary Gaming Experience'], ['Derivco Estonia – Legendary Gaming Experience'], ['Derivco Estonia – Legendary Gaming Experience'], ['Alusta oma teekonda IT arenduskeskuses'], ['Alusta oma teekonda IT arenduskeskuses'], [], ['Alusta oma teekonda IT arenduskeskuses'], ['Alusta oma teekonda IT arenduskeskuses'], ['Alusta oma teekonda IT arenduskeskuses'], ['SOFTWARE DEVELOPER'], ['SOFTWARE DEVELOPER'], [], ['SOFTWARE DEVELOPER'], ['SOFTWARE DEVELOPER'], ['SOFTWARE DEVELOPER'], [], [], [], [], ['Senior Data Modeler'], ['Senior Data Modeler'], [], ['Senior Data Modeler'], ['Senior Data Mo
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import requests
import pandas as pd
from bs4 import BeautifulSoup
r = requests.get("https://worldtable.info/gosudarstvo/tablica-rozhdaemosti-po-godam-rossija.html")
html = BeautifulSoup(r.content)
data = []
table = html.find("table")
for tr in table.find_all("tr"):
    data.append([td.get_text().replace(" ","") for td in tr.find_all("td")])
data = pd.DataFrame(data[1:], columns=["Год", "Количество"])
data["Количество"] = data["Количество"].astype("int")
data["Год"] = data["Год"].str.slice(0,4)
data = data.set_index("Год")
data.plot.line()
plt.show()

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

r = requests.get('https://mfd.ru/marketdata/?id=5&group=16&mode=3&sortHeader=name&sortOrder=1&selectedDate=01.11.2019')

html = BeautifulSoup(r.content, 'lxml')

table = html.find('table', {'id': 'marketDataList'})
rows = []
trs = table.find_all('tr')

for tr in trs:
    tr = [td.get_text(strip=True) for td in tr.find_all('td')]

    if len(tr) > 0:
        rows.append(tr)

data = pd.DataFrame(rows, columns=['Тикер', 'Дата', 'Сделки', 'С/рост', 'С/%',
                                   'Закрытие', 'Открытие', 'min', 'max', 'avg', 'шт', 'руб', 'Всего'])
data = data[data['Сделки'] != 'N/A']
data['С/%'] = data['С/%'].str.replace('−', '-').str.replace('%', '').astype(float)
data = data.set_index('С/%')
data = data.sort_index(ascending=False)

print(data['Тикер'].head())
# Out:
# С/%
# 11.00    ИКРУСС-ИНВ
# 8.14     Мостотрест
# 7.57       Сургнфгз
# 7.05     КурганГКап
# 6.25     КурганГКао
# Name: Тикер, dtype: object
