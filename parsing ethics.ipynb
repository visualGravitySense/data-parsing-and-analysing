# %%
import time
import requests
headers = {"User-Agent": "aawra-python-scraper/1.0 (+http://aawra.ee)"}
#t = time.now()
r = requests.get("url", headers = headers)
#response_time = time.now() - t
#2-3 rps, Crawl-Delay, response.time*2-3
#time.sleep(round(response_time * 3))
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# <ipython-input-7-9466133b340b> in <module>
#       3 headers = {"User-Agent": "ittensive-python-scraper/1.0 (+https://www.ittenasive.com)"}
#       4 #t = time.now()
# ----> 5 r = requests.get("url", headers = headers)
#       6 #response_time = time.now() - t
#       7 #2-3 rps, Crawl-Delay, response.time*2-3
#
# ~/Documents/jupyter/venv/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/Documents/jupyter/venv/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ...

# %%
import requests
from bs4 import BeautifulSoup
headers = {"User-Agent": "ittensive-python-courses/1.0 (+https://www.ittensive.com)"}
r = requests.get("https://video.ittensive.com/data/018-python-advanced/beru.ru/", headers = headers)
html = BeautifulSoup(r.content)

links = html.find_all("a", {"class": "_3ioN70chUh Usp3kX1MNT _3Uc73lzxcf"})
for link in links:
    if str(link).find("Саратов 263") > -1:
        link_263 = link["href"]
    if str(link).find("Саратов 452") > -1:
        link_452 = link["href"]
        
def find_volume (link):
    r = requests.get("https://video.ittensive.com" + link)
    html = BeautifulSoup(r.content)
    volume = html.find_all("span", {"class": ""})
    return int(''.join (i for i in volume[2].get_text() if i.isdigit()))
        
if link_263 and link_452:
    volume_263 = find_volume(link_263)
    volume_452 = find_volume(link_452)
    diff = max(volume_263, volume_452) - min(volume_263, volume_452)
    print (diff)
    
    #r = requests.get("https://video.ittensive.com" + link_263)
    #html = BeautifulSoup(r.content)
    #volume = html.find_all("span", {"class": ""})
    #volume = int(''.join (i for in volume[2].get_text() if i.isdigit()))
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/Documents/jupyter/venv/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/Documents/jupyter/venv/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# ...

# %%
import requests
from bs4 import BeautifulSoup
import lxml


def get_vol(link):
    r = requests.get('https://beru.ru' + link)
    html = BeautifulSoup(r.content, 'lxml')
    volume = html.find_all('span', {'class': '_112Tad-7AP'})
    return int(''.join(i for i in volume[2].get_text() if i.isdigit()))


headers = {"User-Agent": "ittensive-python-courses/1.0 (+www.iitensive.com)"}
r = requests.get('https://beru.ru/search?cvredirect=2&text=%D1%81%D0%B0%D1%80%D0%B0%D1%82%D0%BE%D0%B2',
                 headers=headers)
html = BeautifulSoup(r.content, 'lxml')

links = html.find_all('a', {'class': 'grid-snippet_react-link'})

for link in links:
    if str(link).find('Саратов 263') > -1:
        link_263 = link['href']

    if str(link).find('Саратов 452') > -1:
        link_452 = link['href']

if link_263 and link_452:
    vol_263 = get_vol(link_263)
    vol_452 = get_vol(link_452)
    diff = max(vol_263, vol_452) - min(vol_263, vol_452)
    print(diff)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/Documents/jupyter/venv/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/Documents/jupyter/venv/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# ...

# %%
from bs4 import BeautifulSoup
import requests

headers = {"User-Agent": "ittensive-python-scraper/1.0 (+https://www.ittenasive.com)"}
r = requests.get("https://beru.ru/catalog/kholodilniki/79958/list?cvredirect=3&text=Саратов%20&hid=15450081", headers=headers)
html = BeautifulSoup(r.content)
links = html.find_all("a", {"class": "grid-snippet__react-link"})
#print(html)
for link in links:
    if str(link).find("Саратов 263") > -1:
        link_263 = link["href"]
    if str(link).find("Саратов 467") > -1:
        link_467 = link["href"]

def find_volume(link):
    r = requests.get("https://beru.ru/" + link)
    html = BeautifulSoup(r.content)
    volume = html.find_all("span", {"class": "_112Tad-7AP"})
    volume = volume[2].get_text()
    return int(''.join(i for i in volume[2].get_text() if i.isdigit()))

if link_263 and link_467:
    volume_263 = find_volume(link_263)
    volume_467 = find_volume(link_467)
    diff = max(volume_263, volume_467) - min(volume_263, volume_467)
    print(diff)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-4707d48f7f68> in <module>
#      20     return int(''.join(i for i in volume[2].get_text() if i.isdigit()))
#      21
# ---> 22 if link_263 and link_467:
#      23     volume_263 = find_volume(link_263)
#      24     volume_467 = find_volume(link_467)
#
# NameError: name 'link_467' is not defined

# %%
import requests
from bs4 import BeautifulSoup
import lxml

headers = {"User-Agent": "ittensive-python-scraper/1.0 (+https://www.ittenasive.com)"}
r = requests.get("https://beru.ru/catalog/kholodilniki/79958/list?cvredirect=3&text=Саратов%20&hid=15450081", headers=headers)

def get_vol(link):
    r = requests.get('https://beru.ru' + link)
    html = BeautifulSoup(r.content, 'lxml')
    volume = html.find_all('span', {'class': '_112Tad-7AP'})
    return int(''.join(i for i in volume[2].get_text() if i.isdigit()))


headers = {"User-Agent": "ittensive-python-courses/1.0 (+www.ittensive.com)"}
r = requests.get('https://beru.ru/search?cvredirect=2&text=%D1%81%D0%B0%D1%80%D0%B0%D1%82%D0%BE%D0%B2',
                 headers=headers)
html = BeautifulSoup(r.content, 'lxml')

links = html.find_all('a', {'class': 'grid-snippet_react-link'})

for link in links:
    if str(link).find('Саратов 263') > -1:
        link_263 = link['href']

    if str(link).find('Саратов 452') > -1:
        link_452 = link['href']

if link_263 and link_452:
    vol_263 = get_vol(link_263)
    vol_452 = get_vol(link_452)
    diff = max(vol_263, vol_452) - min(vol_263, vol_452)
    print(diff)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/Documents/jupyter/venv/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/Documents/jupyter/venv/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      60
# ---> 61     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62         af, socktype, proto, canonname, sa = res
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# ...
