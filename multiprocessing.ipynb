# %%
from multiprocess import Pool
from multiprocess import cpu_count

def get_film (url):
    import requests as requests
    from bs4 import BeautifulSoup
    r = requests.get("https://www.kinopoisk.ru/film/111543" + url.strip())
    html = BeautifulSoup(r.content)
    title = html.find("span", {"class": "moviename-title-wrapper"}).get_text()
    tags =html.find_all("td", {"class": "dollar"})
    budget = ""
    sales_www = ""
    if len(tags) > 0:
        sales_www = tags[0].get_text()
        if len(tags) > 1:
            budget = tags[0].get_text()
            sales_www = tags[1].get_text()
            if len(tags) > 2:
                sales_www = tags[2].get_text()
    return [url, title, budget, sales_www]

pool = Pool(cpu_count() *2)
data = []
with open("films.txt", "r") as f:
    result_iter = pool.map(get_film, f)
    for result in result_iter:
        data.append(result)
print (data)
# Out:
# Process ForkPoolWorker-33:
# Process ForkPoolWorker-36:
# Process ForkPoolWorker-34:
# Process ForkPoolWorker-32:
# Process ForkPoolWorker-35:
# Process ForkPoolWorker-37:
# Process ForkPoolWorker-38:
# Process ForkPoolWorker-31:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/process.py", line 313, in _bootstrap
#     self.run()
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/process.py", line 313, in _bootstrap
#     self.run()
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/process.py", line 313, in _bootstrap
#     self.run()
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/process.py", line 313, in _bootstrap
#     self.run()
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/process.py", line 313, in _bootstrap
#     self.run()
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/process.py", line 313, in _bootstrap
#     self.run()
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/process.py", line 313, in _bootstrap
#     self.run()
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/process.py", line 313, in _bootstrap
#     self.run()
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/pool.py", line 114, in worker
#     task = get()
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/queues.py", line 359, in get
#     res = self._reader.recv_bytes()
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/queues.py", line 358, in get
#     with self._rlock:
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-af0c6d171e65> in <module>
#      23 data = []
#      24 with open("films.txt", "r") as f:
# ---> 25     result_iter = pool.map(get_film, f)
#      26     for result in result_iter:
#      27         data.append(result)
#
# ~/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/pool.py in map(self, func, iterable, chunksize)
#     362         in a list that is returned.
#     363         '''
# --> 364         return self._map_async(func, iterable, mapstar, chunksize).get()
#     365
#     366     def starmap(self, func, iterable, chunksize=None):
#
# ~/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/pool.py in get(self, timeout)
#     760
#     761     def get(self, timeout=None):
# --> 762         self.wait(timeout)
#     763         if not self.ready():
#     764             raise TimeoutError
#
# ~/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/pool.py in wait(self, timeout)
#     757
#     758     def wait(self, timeout=None):
# --> 759         self._event.wait(timeout)
#     760
#     761     def get(self, timeout=None):
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/threading.py in wait(self, timeout)
#     556             signaled = self._flag
#     557             if not signaled:
# --> 558                 signaled = self._cond.wait(timeout)
#     559             return signaled
#     560
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/synchronize.py", line 101, in __enter__
#     return self._semlock.__enter__()
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/connection.py", line 219, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/connection.py", line 417, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/Users/dmitrigornakov/Documents/jupyter/venv/lib/python3.8/site-packages/multiprocess/connection.py", line 382, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
